# %%
x=0

if x < 10:
    print(x)
    print('한자리수')
# Out:
# 9
# 한자리수

# %%
y=5

if y > 7:
    print(y)
    print('한자리수')
# Out:
# 10
# 한자리수

# %%
x=100
if x < 100: print(x)

# %%
x = 10000

if x < 10:
    print('1')
elif x <100:
    print('2')
else:
    print('3')
# Out:
# 3

# %%
n=9

if n < 10:
    pass
    print(n*2)
else:
    print(n)

    
    
print(n*3)
# Out:
# 18
# 27

# %%
number=10
if number>10:
    print("박서준")
else:
    print("박진")
# Out:
# 박진

# %%
def power(b,p):
    if p == 1:
        #print(p)
        return b
    m=p//2
    res1 = power(b,m)
    res2 = power(b,p-m)
    out=res1*res2

    return out

power(55,299999)
# Out:
# ...

# %%
def power(b,p):
    if p in memo: return memo[p]
    if p == 1:
        #print(p)
        return b
    m=p//2
    res1 = power(b,m)
    res2 = power(b,p-m)
    out=res1*res2
    memo[p]=out
    return out
memo={}
power(99,999999999999999999999999999)

# %%
9**999999

# %%
a=10
print(bin(a))
print(bin(a>>2))
# Out:
# 0b1010
# 0b10

# %%
a= 100
b= 200

# %%
9**99999
# Out:
# ...

# %%
10**999999
# Out:
# ...

# %%
9**9999999

# %%
1
